# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = sum((y - yp)**2) / len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 227.994
# The Mean absolute error is 11.766

# %% [markdown]
# # HW1
# ## A1
# 我選了 "Chest X-Ray Images (Pneumonia)"
# 這是胸部 X光片, 分成一般跟有肺炎的狀況.
# 若能幫助醫生分析並診斷肺炎, 就能採取有效的方法治癒病人.
# ## A2
# 由 Daniel Kermany, Kang Zhang, Michael Goldbaum 提供.
# 在 2017 年收集了過去五年至廣州婦幼醫院看診的病人資料.
# ## A3
# 影像檔 (Jpeg)
# ## A4
# 是否能正確的診斷肺炎

# %% [markdown]
# # HW2
# ## A1
#
# 1. 載客率
#   * 若能讓空車時間減到最少,不但節省閒置油耗,也能增加收入.
# 2. 客單價(假設以路程計費)
#   * 為了減少閒置並增加收入,優先選擇長途旅客,並避免需要太長時間的排班地點.
# ---
# ## A2
# 1. 交通熱區
#   * 如機場,戲院,百貨公司
#   * 資料可以由 google map 取得
# 2. 特殊活動
#   * 如演唱會,遊行
#   * 由各大活動或售票網站
# 3. 客戶統計資料
#   * 如哪邊的客單價較高, 排班需等待時間較少
# ---
# ## A3
# * 字串與數字組合成的 csv 文字檔, 包含但不限於:
#   * 交通熱區地點, 每小時平均客單價, 每小時叫車數量, 平均排班時間
#   * 特殊活動地點, 活動人數, 活動時間,
# ---
# ## A4
# 收集完資料先進行模擬, 待模擬結果有一定信心後, 實際實行並修正演算法與資料.
# 衡量標準為最高的收入, 或最少的閒置時間.
